# %% [markdown]
# # The Soil footprint of food consumption in Spain
#
# Soil is one of the most vital natural resources for food production. However, agricultural activities contribute to soil degradation, erosion, and loss of fertile land. Different crops require different amounts of soil per kilogram of food produced, a concept known as the soil footprint.
#
# In Spain, the average diet consists of various staple foods such as potatoes, wheat (bread and flour), olives (olive oil), and fruits like oranges, grapes (wine), peaches, and cherries. Each of these crops has a different impact on soil consumption, depending on agricultural practices, land use efficiency, and yield.
#
# This tool provides an easy way to analyze how much soil is "consumed" annually per person based on average food consumption. Using a simple calculation model and data visualization, it helps raise awareness about the impact of food choices on soil sustainability.

# %%
from util.functions_2 import calcular_huella_suelo, interactive_soil_footprint
calcular_huella_suelo()
# Out:
# Kilos de suelo consumidos al año por persona en total: 111.46 kg
#                      Cultivo  Kilos de suelo consumidos (kg/persona/año)
# 0   Vid (Uva de mesa + Vino)                                      13.890
# 1                     Patata                                       3.900
# 2                    Cebolla                                       0.800
# 3  Olivo (Aceituna + Aceite)                                      33.250
# 4       Trigo (Harina + Pan)                                      53.200
# 5                    Naranja                                       3.400
# 6                  Melocotón                                       0.750
# 7                     Cereza                                       0.350
# 8                       Maíz                                       0.500
# 9                   Pimiento                                       1.425

# %% [markdown]
# This script calculates the soil footprint of different crops based on their annual per capita consumption in Spain and their soil consumption rate (kg of soil per kg of food). Additionally, it provides interactive visualizations that allow users to explore how different foods contribute to soil consumption.

# %%
interactive_soil_footprint()
# Out:
# Dropdown(description='Data:', options=('soil footprint', 'total soil lost'), value='soil footprint')
# Dropdown(description='Sorting:', options=('descending', 'by category'), value='descending')
# Output()
